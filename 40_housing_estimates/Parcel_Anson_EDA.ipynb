# %%
import pandas as pd
import numpy as np
import geopandas as gpd

data = gpd.read_file("../00_source_data/anson-parcels")
data.head()
# Out:
#                     ALTPARNO CNTYFIPS CNTYNAME   GISACRES   GNISID  IMPROVVAL  \
# 0               UNION COUNTY      007    Anson   3.542672  1008534        0.0
# 1               NewParcel709      007    Anson   0.004462  1008534        0.0
# 2               NewParcel264      007    Anson   0.000318  1008534        0.0
# 3          ASSESSED IN UNION      007    Anson  31.503410  1008534        0.0
# 4  assessed  in union county      007    Anson   0.188700  1008534        0.0
#
#    LANDVAL LEGDECFULL MADDPREF MADDRNO  ... STRUCT STRUCTNO STRUCTYEAR  \
# 0      0.0       None     None    None  ...   None     None          0
# 1      0.0       None     None    None  ...   None     None          0
# 2      0.0       None     None    None  ...   None     None          0
# 3      0.0       None     None    None  ...   None     None          0
# 4      0.0       None     None    None  ...   None     None          0
#
#   SUBDIVISIO SUBOWNTYPE SUBSURFOWN SUNIT  SZIP  TRANSFDATE  \
# 0       None       None       None  None  None  2022-12-26
# 1       None       None       None  None  None  2022-12-26
# 2       None       None       None  None  None  2022-12-26
# 3       None       None       None  None  None  2022-12-26
# 4       None       None       None  None  None  2022-12-26
#
#                          geometry
# 0  POINT (1608012.361 429959.033)
# 1  POINT (1626508.486 508899.478)
# 2  POINT (1691005.125 449305.302)
# 3  POINT (1614986.389 494392.328)
# 4  POINT (1613144.845 478086.780)
#
# [5 rows x 69 columns]

# %%
data.columns
# Out:
# Index(['ALTPARNO', 'CNTYFIPS', 'CNTYNAME', 'GISACRES', 'GNISID', 'IMPROVVAL',
#        'LANDVAL', 'LEGDECFULL', 'MADDPREF', 'MADDRNO', 'MADDSTNAME', 'MADDSTR',
#        'MADDSTSUF', 'MADDSTTYP', 'MAILADD', 'MAPREF', 'MCITY', 'MSTATE',
#        'MULTISTRUC', 'MUNIT', 'MZIP', 'NPARNO', 'OwnerName2', 'OWNFRST',
#        'OWNLAST', 'OWNNAME', 'OWNNAME2', 'OWNTYPE', 'PARNO', 'PARUSECD2',
#        'PARUSECODE', 'PARUSEDESC', 'PARUSEDSC2', 'PARVAL', 'PARVALTYPE',
#        'PRESENTVAL', 'RECAREANO', 'RECAREATX', 'REVDATETX', 'REVISEDATE',
#        'REVISEYEAR', 'SADDNO', 'SADDPREF', 'SADDSTNAME', 'SADDSTR',
#        'SADDSTSUF', 'SADDSTTYP', 'SALEDATE', 'SALEDATETX', 'SCITY', 'SITEADD',
#        'SOURCEAGNT', 'SOURCEDATE', 'SOURCEDATX', 'SOURCEREF', 'SSTATE',
#        'STCNTYFIPS', 'STFIPS', 'STNAME', 'STRUCT', 'STRUCTNO', 'STRUCTYEAR',
#        'SUBDIVISIO', 'SUBOWNTYPE', 'SUBSURFOWN', 'SUNIT', 'SZIP', 'TRANSFDATE',
#        'geometry'],
#       dtype='object')

# %%
data.shape
# Out:
# (18874, 69)

# %%
((data.isna().sum()*100)/data.shape[0]).sort_values(ascending=False)[:10] #basically, several columns are missing data completely
# Out:
# OWNTYPE       100.0
# OwnerName2    100.0
# OWNLAST       100.0
# OWNNAME2      100.0
# SCITY         100.0
# PARUSECD2     100.0
# PARUSECODE    100.0
# PARUSEDESC    100.0
# PARUSEDSC2    100.0
# PARVAL        100.0
# dtype: float64

# %%
remove= data.columns[data.isna().all()].tolist()
print (f"{len(remove)} columns have all NAs")
data.drop(remove, axis=1, inplace=True) #dropping columns with all NAs
data.shape
# Out:
# 41 columns have all NAs
# (18874, 28)

# %%
data.columns

## ALTPARNO - An alternate local parcel number for the parcel record 
## GISACRES - The area of the feature in acres - computed from the GIS, this is not the recorded area.
## GNISID - The Geographic Names Information System identifier for the local place for the parcel.  The default value is the county GNIS number but as this data set develops, individual parcels may have a GNIS identifier, such as local parks or attractions.
## IMPROVVAL - The value of the improvements on the parcel in dollars.
## LANDVAL - The value of the land represented by the parcel in dollars.
## NPARNO - The local parcel number with the state and county FIPS added to the beginning of the local parcel number (PARNO).
## OWNNAME- The full name of the primary property owner (surface owner).
## RECARENO - The record or recorded area as a numeric field (deed acres).
# Out:
# Index(['ALTPARNO', 'CNTYFIPS', 'CNTYNAME', 'GISACRES', 'GNISID', 'IMPROVVAL',
#        'LANDVAL', 'MAILADD', 'MCITY', 'MSTATE', 'MULTISTRUC', 'MZIP', 'NPARNO',
#        'OWNNAME', 'PARNO', 'PARVALTYPE', 'RECAREANO', 'RECAREATX', 'SITEADD',
#        'SOURCEAGNT', 'SOURCEREF', 'SSTATE', 'STCNTYFIPS', 'STFIPS', 'STNAME',
#        'STRUCTYEAR', 'TRANSFDATE', 'geometry'],
#       dtype='object')

# %%
data.head()
# Out:
#                     ALTPARNO CNTYFIPS CNTYNAME   GISACRES   GNISID  IMPROVVAL  \
# 0               UNION COUNTY      007    Anson   3.542672  1008534        0.0
# 1               NewParcel709      007    Anson   0.004462  1008534        0.0
# 2               NewParcel264      007    Anson   0.000318  1008534        0.0
# 3          ASSESSED IN UNION      007    Anson  31.503410  1008534        0.0
# 4  assessed  in union county      007    Anson   0.188700  1008534        0.0
#
#    LANDVAL MAILADD MCITY MSTATE  ... SITEADD             SOURCEAGNT SOURCEREF  \
# 0      0.0  " "" "  None   None  ...    None  Anson County Assessor         _
# 1      0.0  " "" "  None   None  ...    None  Anson County Assessor         _
# 2      0.0  " "" "  None   None  ...    None  Anson County Assessor         _
# 3      0.0  " "" "  None   None  ...    None  Anson County Assessor         _
# 4      0.0  " "" "  None   None  ...    None  Anson County Assessor         _
#
#   SSTATE STCNTYFIPS STFIPS  STNAME STRUCTYEAR  TRANSFDATE  \
# 0     NC      37007     37      NC          0  2022-12-26
# 1     NC      37007     37      NC          0  2022-12-26
# 2     NC      37007     37      NC          0  2022-12-26
# 3     NC      37007     37      NC          0  2022-12-26
# 4     NC      37007     37      NC          0  2022-12-26
#
#                          geometry
# 0  POINT (1608012.361 429959.033)
# 1  POINT (1626508.486 508899.478)
# 2  POINT (1691005.125 449305.302)
# 3  POINT (1614986.389 494392.328)
# 4  POINT (1613144.845 478086.780)
#
# [5 rows x 28 columns]

# %%
list(data['OWNNAME'].unique())
# Out:
# [None,
#  'TAYLOR JODY MATTHEW II &',
#  'STATEOF NORTH CAROLINA',
#  'STATE OF NORTH CAROLINA',
#  'TC&I TIMBER CO LLC',
#  'ON POINT VENTURES LLC',
#  'DELIGERO DELL E &',
#  'DELIGERO SIMPLICIO E &',
#  'ROSS TAMMY A',
#  'JARMAN HAILY A',
#  'BUTCHER ROBERT  & WIFE',
#  'DONALDO ANGELA S  &',
#  'ALBURO MARIA PAZ R',
#  'COVER JOHN & WIFE',
#  'DELIGERO PASCUAL & WIFE',
#  'HONSTEAD TERESA & PRESTON A',
#  'MCFARLAND WILLIAM &',
#  'TOWNSEND LENNOX',
#  'ZAREMBY DAVID M & WIFE',
#  'VICERA MONTANA L',
#  'SHIRLEY ROBERT JR &',
#  'PRECIADOS VIRGILIO C',
#  'ESTEP JAMES & WIFE JOANNE',
#  'XAVIER STEPHEN & WIFE',
#  'URAM THOMAS G  & WIFE',
#  'BERGES LUIS E & WIFE',
#  'ORELLANA JENNIFER ANDREA',
#  'CARDILICCHIA TINA  &',
#  'PETERS JAMES A',
#  'COLON-MELENDEZ YVETTE',
#  'BRASWELL SHANNON LEE & WIFE',
#  'CROSSINGS PROPERTY OWNERS ASS',
#  'DUKE ENERGY PROGESS INC',
#  'JACOBS JAMES ANDREW & WIFE',
#  'GUASCH SUZANNE',
#  'KAPLAN DAVID & WIFE',
#  'PETERSEN EARLE D  &  WIFE',
#  'BROSKY THOMAS ANTHONY II &WIFE',
#  'KHATIB RANDA MNAYMNEH',
#  'HARRISON CASANDRA',
#  'JACKSON HORACE & WIFE',
#  'PEREZ RAFAEL &',
#  'BENT MICHAEL S & WIFE',
#  'BENITEZ MELIDY NIETO',
#  'BARTLE MARK A',
#  'PHIFER WILLIAM & WIFE',
#  'GRANT WESLEY',
#  'GORDON ROBERT ETAL',
#  'SCOTT CYRIL L & WIFE',
#  'DEMARCO JOHN TRUST',
#  'HARRISON CASANDRA &',
#  'NORTHERN CROSSING REALTY LLC',
#  'CERNY CHARLES J  &  WIFE',
#  'GRIMM JAMES H & WIFE',
#  'MCMANUS JASON & JAMES NOVEMBER',
#  'HAYNICK TIMOTHY J & WIFE',
#  'ROSS CHARLES L JR  & WIFE',
#  'LYFORD JONATHAN MICHAEL',
#  'HOFER BETTE A',
#  'HOFER CHRISTOPHER K & WIFE',
#  'DOURNEY DANIEL V & WIFE',
#  'GOMEZ MAXIMINO RANGEL',
#  'GARZON PEDRO P &',
#  'TSUI YING KIT FRANCO & WIFE',
#  'DELIGERO PASCUAL E  &',
#  'GILMORE KEMBERLIE DAWN',
#  'ROMANO JOSEPH & WIFE',
#  'RUBAINE KEITH O &',
#  'PEREZ ALFREDO & WIFE',
#  'OCTAVO BRAULIO XALATE & WIFE',
#  'KENNELL KURT & SPOUSE',
#  'REDDICK ROSETTA',
#  'MCVICKER BRIAN J',
#  'WALDRON W JEFFREY & WIFE',
#  'JIMENEZ ROBERT J & WIFE',
#  'CLARK LISA ANN',
#  'THOMSON STEVEN  &',
#  'SMITH GEORGE EDWIN & WIFE',
#  'SMITH GEORGE EDWIN &  WIFE',
#  'ALLEN BRIAN L & LYNN M MYRICK',
#  'MILLER MICHAEL D',
#  'THYROFF JOHN E  &  WIFE',
#  'LEIMBACH SCOTT  & WIFE',
#  'USON ALEX M  & WIFE',
#  'TOLEDO MA SOCORRO A',
#  'TOCHIP BECKY T',
#  'JIMENEZ ROBERTO J & WIFE',
#  'MEAGHER BENJAMIN M & WIFE',
#  'REGALA FRANCIS M AND WIFE',
#  'WOOTEN WILLIAM JOSEPH',
#  'SENERPIDA PAUL KIM & WIFE',
#  'PETERSON ROBERT FOY & SYLVIA',
#  'SIMMONS BRAD A & SPOUSE',
#  'DORTON DANIEL NELSON &',
#  'JONES FRANK JR & WIFE',
#  'KISH STEPHEN WILLIAM & WIFE',
#  'COLEMAN CARL JOSEPH',
#  'TRAYWICK RONALD LEE',
#  'MILLER RONALD J & WIFE',
#  'MISENHEIMER JOHN GORMAN ETAL',
#  'MORAIS DAVID C',
#  'CARISMA SAMUEL F & WIFE',
#  'DIAZ JUAN T & WIFE',
#  'LOEB PETER E',
#  'MOORE GARMON A & WIFE',
#  'HUTSON TRACEY REVOC TRUST',
#  'REVELL SILAS G III',
#  'GARDNER BELINDA S  &',
#  'DANIELS JOHN S & WIFE',
#  'MORENO ALBERTO & WIFE',
#  'KLUTTZ WARREN R & WIFE',
#  'FRANCIS CHARLES K',
#  'PENNELL DARRYL W ET AL',
#  'COLLETTE KELLY A',
#  'MYERS PROPERTIES OF THE',
#  'MEAGHER GREG A &',
#  'ARCE ROBERT',
#  'KASNAT LAND HOLDING INC',
#  'BILL-MAR INC',
#  'PAULK JOSEPH SCOTT & WIFE',
#  'PETERS JAMES WYATT',
#  'GOODWIN JOSEPH MICHAEL &',
#  'TAYLOR JOAN & HUSBAND',
#  'BURROUGHS JABIE LEAK & WIFE',
#  'GHARIB MORTEZA',
#  'MIRANDA-CORTEZ BRIANNA',
#  'TARLETON MARK G & SPOUSE',
#  'SIGMAN STEVEN W',
#  'HUNEYCUTT DERRY LEON',
#  'KEEGAN LINDSAY',
#  'MEAGHER NORMAN J &',
#  'LAMBERT THOMAS W  &  WIFE',
#  'PRECIADOS ARSENIA V',
#  'YAP HENRY  &',
#  'KRICHMAR JEFFERY & WIFE',
#  'LILES ELISHA & WIFE',
#  'KEANE CHRISTOPHER & JULIET',
#  'SMITH DANNY PHILLIP',
#  'HICKEY DIANE ET AL',
#  'LABRADOR STEVE & WIFE',
#  'CASTRO ZEUS DANIEL  & WIFE',
#  'THE CROSSINGS LLC',
#  'LOPEZ MANUEL J  &  WIFE',
#  'TOV II LLC',
#  'AYDINEL ZAFER & WIFE',
#  'ABOLAFIA ISSAC D &',
#  'VERA ANDREW A  & WIFE',
#  'SCHARF FAMILY TRUST',
#  'LEAR STEPHEN M & WIFE',
#  'RUXLOW FAMILY THE TRUST',
#  'HALL FREDERICK',
#  'NOVEMBER JAMES JR',
#  'CASTRO ZEUS DANIEL &  WIFE',
#  'SAJEWICH DOUGLAS & WIFE',
#  'LOTS 13 & 26 THE CROSSING LLC',
#  'WOLLISTON DEON L  &',
#  'PAPOO LLC',
#  'LEIMBACH SCOTT & WIFE',
#  'BENDER GARY JOE',
#  'BURROUGHS DWIGHT GENE',
#  'DUKE ENERGY PROGRESS INC',
#  'HONEYCUTT JENNIE B & HUSBAND',
#  'WALL WILLIAM BATTLE III & WIFE',
#  'MADDRY SARAH BRIGMAN',
#  'WARNOCK MARY MARTHA ETAL',
#  'WARNOCK DOUGLAS K & WIFE',
#  'WALL BILLIE LYNN & WIFE',
#  'WALL BILLY LYNN & W & WIFE',
#  'NORTHCUTT DOROTHY',
#  'WALL PATTIE L HEIRS',
#  'NEAL JOHN C JR & WIFE',
#  'RIVERS EDGE OF ANSON CO LLC',
#  'RATLIFF GEAMES JUNIUS',
#  'JOHNSON BEVERLY',
#  'INGRAM FANNIE LEE',
#  'BACON JOHN EDWARD JR &',
#  'WYATT GORMAN RUSSELL &',
#  'NORTHCUTT DOROTHY W',
#  'WALL BILLY LYNN & WIFE',
#  'PESCE VICKIE S & HUSBAND',
#  'ELLERBE LAURA O',
#  'AZAR CHRIS T & CATHY',
#  'SHEPPARD DEWEY EVANS JR &',
#  'PESCE SAM DAVID',
#  'ELLERBE WILLIE L',
#  'MOUZON SALLIE MAE',
#  'ELLERBE LAURA',
#  'ELLERBE WILLIE L HEIRS',
#  'ELLERBE JAMES',
#  'LILES GEORGIANA',
#  'ELLERBE WILLIE LEE',
#  'DIXON ELIZABETH HEIRS &',
#  'SHEPPARD JESSE EVANS & WIFE',
#  'GRANT ROBERT BLAINE &',
#  'MCLEAN TONY & WIFE',
#  'MCRAE PARTHINE C HEIRS',
#  'THOMAS HELEN ANN W ET/AL',
#  'SHEPPARD HOLDINGS LLC',
#  'SANTEE RIVER LLC',
#  'SHEPPARD HUNTER MAULDIN',
#  'CLODFELTER TERRY LYNN & WIFE',
#  'CLODFELTER T LYNN & WIFE',
#  'CLODFELTER T LYNN',
#  'CLODFELTER TERRY LYNN',
#  'HARRIS OSBORN',
#  'MCCOY EMMA',
#  'TROGDEN L H',
#  'MOBLEY CHARLES L JR',
#  'DIXON ROY JR',
#  'WADE ALAN ET AL',
#  'LINEHAN MARIE HEIRS',
#  'WOMBLE CHAPEL AME ZION CHURCH',
#  'BOGGAN CLAYTON A JR',
#  'BENNETT JAMES W & BEATRICE F',
#  'BOGGS MATERIALS INC',
#  'WITTS ESTHER V',
#  'DIXON JUDY-ANN J',
#  'MILLS JODY L',
#  'FRYE WALTER O JR  &',
#  'MCGREGOR KATHALEEN P LE',
#  'BENNETT URIAS JAMES',
#  'BENNETT U JAMES',
#  'BENNETT BESSIE',
#  'STURDIVANT VANCINE ROBINSON &',
#  'HEDRICK B V GRAVEL & SAND',
#  'TUCKER DAVID N',
#  'DIXON LARRY T JR',
#  'CHAMBERS ANTHONY DWAYNE',
#  'DIGGS KATRINA & RONALD ROSS',
#  'ROSS RONALD & WIFE',
#  'HEDRICK B V GRAVEL & SAND CO',
#  'THOMAS WEAVER K & WIFE',
#  'DIGGS HENRY O',
#  'MARTIN MARIETTA MATERIALS INC',
#  'BENNETT BETTY T & LEVANDER',
#  'GLADDEN BARBARA TILLMAN',
#  'HOUGH ROBERT & WIFE',
#  'HOUGH ROBERT J',
#  'DIGGS HENRY ONEIL',
#  'LIDGE ALFRETA &',
#  'SPENCER RACHEAL',
#  'HEW PROPERTIES LLC',
#  'PRESBYTERIAN CHURCH',
#  'QUICK SHELIA',
#  'FLOWERS R',
#  'LEAK ETHEL MAE',
#  'FAIREL JANIE BELLE',
#  'UNKNOWN',
#  'HORNE CHARLES HARRISON II',
#  'SPENCER CHARLIE B HEIRS',
#  'WALL SIMON HEIRS',
#  'WALL B L HEIRS',
#  'SPENCER CHARLIE HEIRS',
#  'WALL B R JR & ANNIE & E C WALL',
#  'LEAK GASTON JULIUS',
#  'WELLS ELISE CHILDS ETAL',
#  'LEAK ANDREW JACKSON',
#  'LEAK GASTON',
#  'BOGGAN CLAYTON A JR &',
#  'PEE DEE CHURCH OF DELIVERANCE',
#  'MCGREGOR KATHLEEN PATRICIA',
#  'MEACHUM C A',
#  'BENNETT JULIA',
#  'SPENCER CHARLES & LENA',
#  'WILLIAMS HARLEE HEIRS',
#  'ELLERBY JAMES HEIRS',
#  'DIXON JACKSON HEIRS',
#  'WILLIAMS J HUIE HEIRS',
#  'CREWS KATIE W',
#  'SPENCER CHARLIE & LENA HEIRS',
#  'WALL JAMES THOMAS',
#  'POWE THOMAS L & DEMEKA S',
#  'CASON JOHN HEIRS',
#  'DEBERRY LILLIE F HEIRS',
#  'PRATT HARRIET L',
#  'PRATT LEE',
#  'HARRIS L T & GURNELL S',
#  'DEBERRY FLORENCE HEIRS',
#  'ROBINSON CEMETERY',
#  'PRATT JOHNNY & GARLETHA TR',
#  'COVINGTON JEANETTE',
#  'MILLER DONNIE HEIRS',
#  'ROBINSON DOROTHY MAE',
#  'COPELAND GROVER LEE',
#  'TIAA TIMBERLANDS II LLC C/O',
#  'CRUM IRIS L SPENCER',
#  'HENDERSON MARY L',
#  'PRATT ALEXANDER',
#  'SHEPPARD WOOD PRODUCTS INC',
#  'JMG LAND & TIMBER INC',
#  'BENNETT BETTY T &',
#  'CROWDER EFFIE G HEIRS',
#  'COPELAND GROVER LEE &',
#  'CROWDER HAROLD LEE  HEIRS',
#  'HARRIS GERALD A & WIFE',
#  'LOPEZ-CAMPOS JOSE ADRIAN ETAL',
#  'CROWDER FANNIE LEE (BUCKMAN)',
#  'BROWN WINNIE JANE',
#  'CROWDER DENNIS &',
#  'CROWDER DENNIS & JOYCE I',
#  'BOLIN JERRY D AND WIFE',
#  'BOLIN JERRY D & WIFE',
#  'JOHNSON BERNICE',
#  'BROWN WINNIE MARGARET',
#  'REED JERLETHA C',
#  'LILLY IDA B HEIRS',
#  'MORRISON QUEEN COPELAND',
#  'COPELAND IRENE',
#  'DIGGS JOSEPH &',
#  'DIGGS JOE HEIRS',
#  'COPELAND GROVER &',
#  'MORRISON QUEEN',
#  'LILES MITCHELL JR',
#  'MOUZON SALLIE ELLERBE & MATTHE',
#  'HARRIS RUBY S &',
#  'BROWN BERNARD',
#  'BROWN BERNARD WIFE',
#  'SPENCER DERIC A & CAROLYN M',
#  'BENNETT MOZELL',
#  'MCRAE ROBERT & MELINDA MCRAE',
#  'JOHNSON MONTEZA',
#  'ALLEN JEREMIAH HEIRS',
#  'DIGGS JAMES H & LILLIE',
#  'DIGGS LAURENCE & EASTER H',
#  'FORGAYS REGINALD E & WIFE',
#  'STURDIVANT WILLIAM L SR LE &',
#  'DOUBLE H RENTALS LLC',
#  'JOHNSON MONTISA',
#  'WESSELS DILLIAM ALAN',
#  'ELLERBY ANNIE LE',
#  'SPENCER JOHN D HEIRS',
#  'SPENCER JOHN HEIRS',
#  'ELLERBY MELTON SR',
#  'PRATT JOHNNY & GARLETHA',
#  'HOUSTON DEBORAH S',
#  'ALLEN HANNAH L LE &',
#  'YANG FUAMVAAM & SPOUSE',
#  'MILLER PATRICIA L',
#  'GILES EVA MAE',
#  'SPENCER JAMES C & RUTH',
#  'STURDIVANT JIMMIE CHARLES & WI',
#  'JLT PROPERTIES LLC',
#  'SPENCER CLAUDE A & MARIE C',
#  'RUSSELL JANE RATLIFF',
#  'LITTLE WATT HEIRS',
#  'CENTENARY AME ZION CHURCH',
#  'DEW DELLA LITTLE ET/AL',
#  'CENTENARY METHODIST CHURCH',
#  'BURGAN PAMELA ROSE/TERRIE DENI',
#  'LITTLE BOBBIE J',
#  'EFIRD JEFFREY CHAD JR & WIFE',
#  'HODGE MARY L',
#  'HUNEYCUTT LEONARD K & WIFE',
#  'HODGE GEORGE C & WIFE',
#  'GADDY KATIE E &',
#  'WEST JAMES & SAMANTHA',
#  'PRATT CLARA LINDSEY',
#  'ROBINSON CARL HEIRS',
#  'ROBINSON GEORGE & DIANE L',
#  'ROBINSON GEORGE & WIFE',
#  'BAILEY LAWRENCE H &',
#  'MELVIN THOMASINA ROBINSON',
#  'ROBINSON WILLIE B',
#  'MATTS PROPERTIES INC',
#  'RICHMOND COUNTY',
#  'CLODFELTER TERRY LYNN ETAL',
#  'ROBINSON HOWARD L',
#  'FULLER INEDA T',
#  'SHEPPARD ELGIE & WIFE',
#  'SHEPPARD DEWEY & WIFE',
#  'PEE DEE ORCHARDS',
#  'GREENE CHESLEY M & ANDREA J TR',
#  'SHEPPARD BOBBY GRAHAM JR',
#  'LITTLE CLARENCE ET/AL',
#  'CEMETERY',
#  'SCHARBARTH ROBERT S & WIFE',
#  'BOGGAN CLAYTON A JR TRUSTEE',
#  'NEAL JENNIFER ET AL',
#  'CORNWELL JAMES EDWIN',
#  'HOWELL DAVID SCOTT & KELLY C',
#  'CHRISTIAN ELIZABETH LILES',
#  'POPLIN SHELBA B ET AL TR',
#  'LILES CAROL ANN (LAWHORN)ET AL',
#  'NEAL JENNIFER ETAL',
#  'CLODFELTER TERRY L &',
#  'LILES NANCY DEITZ',
#  'TUCKER GENE ED JR &',
#  'GAINEY LAQUITA D',
#  'PATRICK DAVID H LE &',
#  'MEACHUM LORETTA F BARATS',
#  'CLODFELTER T LYNN &',
#  'GREENE STEPHEN C &',
#  'PEE DEE ORCHARDS INC',
#  'MILLS JODY',
#  'INGRAM SHARON',
#  'WALL DEMETRIUS &',
#  'SPENCER WAYNE & JOAN',
#  'INGRAM SHARON DIGGS &',
#  'INGRAM MARILYN',
#  'WILLIAMS CARLTON D',
#  'WILLIAMS CARLTON DAVID &',
#  'SELLERS FREDDIE R & HELEN M',
#  'SELLERS THOMAS & WIFE',
#  'PHIFER JANICE SUE',
#  'STURDIVANT VANCINE ETAL',
#  'SPENCER MATTIE D LE',
#  'TUCKER DAVID N & DYLAN N',
#  'STURDIVANT WILLIAM & VANCINE',
#  'BIG ANTLER RANCH LLC',
#  'BATES AARON & WIFE',
#  'BATES AARON D AND WIFE',
#  'MALSGATE WOODS LLC',
#  'SNYDER GEORGE W HEIRS',
#  'LITTLE MARY CARLISLE &',
#  'BWW III FARMS INC',
#  'SHADYS SENSATION LLC',
#  'PAXTON J & E POULTRY FARMS INC',
#  'LITTLE WILLIAM B II FAMILY TR',
#  'BELL CREEK LAND & TIMBER LLC',
#  'ALTMAN JULIA L',
#  'BOULDER ASSOCIATES LLC',
#  'ROSS JONATHAN MARK',
#  'EDWARDS TIMBER CO INC',
#  'ROSS JONATHAN MARK ROSS ET AL',
#  'ROSS MARK LITTLE',
#  'JORDAN TWO LLC',
#  'MARTIN JASON & WIFE',
#  'PATE JAMES THOMAS',
#  'PATE LINDA E',
#  'GIBBONS FARM LLC',
#  'SAVANNAH CHAPEL',
#  'SAVANNAH CHAPEL CHURCH',
#  'PATE JAMES THOMAS & LINDA E',
#  'KIRBY ELGIA & LEROY INGRAM',
#  'FULCHER STACY D',
#  'BTG PACTUAL OEF PROPERTY 2 LP',
#  'PARRISH ROBERT MILTON ET AL',
#  'BROWN ETHAN KYLE & WIFE',
#  'USREY SANDRA',
#  'PRICE JAMES EDWARD',
#  'HENDERSON GROVE COLORED CHURCH',
#  'THOMAS DAVID CLIFFORD',
#  'WALLACE THOMAS EDWARD',
#  'SAVANNAH METHODIST CHURCH',
#  'LANDEN LEMUEL THOMAS III ETAL',
#  'W L INGRAM PROPERTIES LLC',
#  'TAYLOR EXCHANGE LLC',
#  'KELLER NICHOLAS ZANE & WIFE',
#  'GOODWIN JOSEPH M &',
#  'MCSWAIN JAMES L &',
#  'KIRK ALLEN R &',
#  'GOODWIN LYNDIA YVONNE',
#  'ALBERGHINI MARK K AND SPOUSE',
#  'WERNER GARY CHARLES &',
#  'GENTRY BASSIL SCOTT & WIFE',
#  'GEIGER PATRICK',
#  'BARCEL JAMES M',
#  'THOMSON DAVID NEIL & WIFE',
#  'HARGETT ROBERT DELWYN',
#  'ANDERSON DRU C & WIFE',
#  'ANDERSON DRU CAPELL & WIFE',
#  'POISSON FREDERICK D JR &',
#  'POISSON FREDERICK D & &',
#  'POISSON FREDERICK D &',
#  'JMG LAND & TIMBER INC &',
#  'EVERETT DEVELOPMENT LLC',
#  'SMITH FELIX & WIFE DEBBIE &',
#  'SHACKLEFORD DAVID WAYNE &',
#  'EVERETT JOSEPH C',
#  'ANSON COUNTY HISTORICAL SOCIET',
#  'MARBRO HOLDINGS LLC',
#  'EDWARDS TIMBER COMPANY INC',
#  'SMITH DONALD W',
#  'HARGETT ROBERT DELWYN  & WIFE',
#  'CARDONA JORGE & MONICA',
#  'SNYDER WADE H &',
#  'POISSON FREDERICK D JR ET/AL',
#  'JARRELL BUDDY HUGH & WIFE',
#  'JARRELL EMILY W',
#  'MAIB HUNTING LEASE PROP LLC',
#  'JMG LAND & TIMBER INC & OLD',
#  'ANSON COUNTY',
#  'BARRINGER JAMES T',
#  'ONE SHOT PROPERTIES LLC',
#  'ALLEN SAMUEL ERNEST',
#  'COX KENNETH T & WIFE',
#  'JAMES NATHAN',
#  'KELLY MATTHEW CHARLES',
#  'HEDRICK BV GRAVEL & SAND CO',
#  'MOSS ESTATES LIMITED PARTNERSH',
#  'CLARK CHARLES TIMOTHY &',
#  'CLARK ALAN RAY & WIFE',
#  'CLARK ALAN R & WIFE',
#  'CLARK ALAN RAY & WIFE ANITA G',
#  'DEMOPOULOS WILLIAM',
#  'CLARK JOHN LOGAN & JAMES LUCAS',
#  'CULP HENRY W III',
#  'ALLEN DUSTIN',
#  'VAUGHN DAVID E JR ET AL LE',
#  'HUNTER LAND & TIMBER LLC',
#  'STURDIVANT CALEB & CATHERINE',
#  'ANSON PROPERTIES LLC',
#  'ROCKY HILL CHURCH AME ZION',
#  'RUBY ORCHARDS LLC',
#  'NC ELECTRIC MEMBERSHIP CORP',
#  'CLARK JOANN R',
#  'CLARK JOANNE R',
#  'LEGACY RENTALS OF NC LLC',
#  'MORRIS DOUGLAS R SR & WIFE',
#  'TAYLOR BRUCE B JR',
#  'MCCORMICK HARVEY J JR & MARY H',
#  'FLOWERS HAZE HOOVER &',
#  'SPENCER THOMAS E',
#  'SPENCER JAMES HENRY',
#  'CLARK MOUNTAIN LLC',
#  'TUCKER CHARLES C LE',
#  'HELMS CYNTHIA (SIKES)',
#  'SELLERS SHALAR DEAN JR & WIFE',
#  'HATTON MARY &',
#  'CONNELLY MARY LOU W',
#  'JOHNSON NATHAN DARELL & WIFE',
#  'POE HAROLD',
#  'WALL CLINTON SR',
#  'ROBINSON BERTHA L',
#  'LEE FELESHA BENNETT &',
#  'SCARBOROUGH DONALD LOGAN',
#  'SHORT GEORGE D &',
#  'MOUZON MATTHEW & SALLIE E',
#  'PEGUES ADDIE',
#  'DIGGS JOSEPH  ET AL',
#  'STURDIVANT WILLIAM LAFAYETTE &',
#  'STURDIVANT CLARENCE E',
#  'MORRIS BARBARA MELTON & HUSBAN',
#  'PEE DEE ELECTRIC MEMBERSHIP',
#  'STURDIVANT JOSEPHINE K',
#  'FAIR TERESA W',
#  'THOMAS IDA KNOTTS HEIRS',
#  'RATLIFF LAURA HEIRS',
#  'LAXMIMATA LLC',
#  'MORGAN NATHAN LEE',
#  'RATLIFF ALBERTA',
#  'ODOM NANCY H',
#  'KNOTTS W H SR',
#  'DIXON ROY SR & ROY DIXON JR',
#  'BV HEDRICK GRAVEL & SAND CO',
#  'CHEWNING EUGENE G JR',
#  'STEWART PATTY ANN',
#  'TILLMAN ODELL & ROBERTA',
#  'TILLMAN ODELL & WIFE',
#  'LILES ERVIN THOMAS & WIFE',
#  'PEGUES WILLIAM T',
#  'INGRAM WINNIE CRAWFORD &',
#  'LINDSEY JAMES E',
#  'ROBINSON THELMA &',
#  'DEWS ROASLIND GILES',
#  'HARRIS JAMES THOMAS &',
#  'BENNETT P WALKER',
#  'LINDSEY ESTER',
#  'INGRAM ROBERT J & WINNIE C',
#  'ROCK HILL BAPTIST CHURCH',
#  'BURNS WILEY HEIRS',
#  'CENTENARY CHURCH',
#  'BARNHILL RONALD LEE',
#  'TUCKER DAVID N & DYLAN NEAL',
#  'SPENCER GWENDOLYN &',
#  'ASBURY DORIS R & THOMAS E',
#  'MASON DONALD LEE & JANICE B',
#  'GROOM REGINA BATTY & HUSBAND',
#  'MASON DON L & JANICE B',
#  'ROGERS MIRIAM MAYS',
#  'ELIZABETH PEE DEE CHURCH',
#  'RATLIFF SAUNDRA JEAN',
#  'COOK BRYAN L',
#  'GOODWIN JOAN LUCILLE &',
#  'SMITH TERRISA GAIL MASON &',
#  'DAWKINS NELLIE & CLARICE SPENC',
#  'RATLIFF LEROND ET AL',
#  'ASBURY DORIS R',
#  'H & H WOODYARD',
#  'SPENCER CORNELIA',
#  'DUNLAP HAYWOOD PARKER JR',
#  'DIGGS FRONTIS HEIRS',
#  'WALL BILLIE L &',
#  'SPENCER DEBORAH T ET/AL',
#  'HONEA TIMOTHY ALLEN',
#  'VELAZ-FAIRCLOTH MARIA',
#  'WADE LARRY',
#  'BURKE NELLIE HEIRS',
#  'ROBINSON H G HEIRS',
#  'JENKINS RAMONA L',
#  'KELLY M DAVID & N DIANE',
#  'LITTLE FAMILY LIMITED',
#  'THOMAS MARSHALL HOYT &',
#  'BORDEN LLOYD A',
#  'PORTER REGINALD J & WIFE',
#  'BARRIER FRANCIS LE',
#  'WOODS RANDY ALLEN',
#  'BARRIER FRANCES P LE',
#  'SPENCER REGINA RENEE',
#  'HARRINGTON ANNA',
#  'ROWE CHRISTINE A & HUSBAND',
#  'SINGLETARY AMINAH',
#  'MIXA DAWN & MATTHEW MIXA',
#  'HEDRICK B V GRAVEL AND SAND',
#  'PORTER JAMES ET/AL',
#  'PORTER JAMES A',
#  'GODDARD BRENT P &',
#  'WILLIAMSON STEPHEN T',
#  'THOMAS JOSHUA MARK',
#  'HINSON CEMETERY',
#  'BROOKS BEULAH V',
#  'ELLIOTT MICHELLE R',
#  'SMITH ANDRE TYRELL & AALIYAH N',
#  'HELMS JAMES TRAVIS',
#  'CORNWELL JAMES EDWIN & RITA D',
#  'THOMAS JOHN GREGORY & BERRY C',
#  'RATLIFF LAURA MAE &',
#  'CHERRY SHIRLEY B',
#  'MOORE LUCILLE R DR',
#  'AMC REAL ESTATE LLC',
#  'TAMARACK TIMBERCO NC LLC',
#  'LEE STEPHEN B & WIFE',
#  'VAZQUEZ IVAN & WIFE',
#  'LITTLE WILLIAM B II MARTIAL TR',
#  'ROWELL MARY F',
#  'ROWELL J LEE & WIFE',
#  'DIGGS ELIZABETH C ETAL',
#  'H&H WOODYARD INCORP A NC CORP',
#  'LITTLE DELORES',
#  'CAPLE ANTHONY E',
#  'LITTLE RICKETTS & CO LLC',
#  'LITTLE LORENZA',
#  'J & E PAXTON POULTRY FARMS INC',
#  'COX JAMES T & HAZEL S',
#  'STURDIVANT JAMES PAUL',
#  'CAUSEY PRESTON LEE &',
#  'WESTBROOK ETHAN COLE &',
#  'WESTBROOK ETHAN C AND WIFE',
#  'UHURU VALIANT IMANI & ORA C',
#  'LITTLE JEANETTA',
#  'LITTLE LESSIE S',
#  'LITTLE CARL VERNON &',
#  'MIMS FRANKLIN E &',
#  'BUTLER JAMES MARC &',
#  'PRATT LIZZIE HEIRS',
#  'CAPLE R LESTER & NELLIE W',
#  'CAPLE E C HEIRS',
#  'CAPLE JAMES POSTELL & ELIZABET',
#  'CAPLE JAMES P & ELIZABETH',
#  'CAPEL LARRY E & YUETTE R',
#  'GAINEY KATINA',
#  'GAINEY RUTH CAPEL',
#  'CAPEL MICHAEL SYLVESTER &',
#  'CLEMONS BRACK O & WIFE',
#  'SWICEGOOD KENNETH WAYNEJR ETAL',
#  'ALLEN BRUCE G  LE & WIFE',
#  'WARFEL MYLA DEE',
#  'ALLEN BRUCE G LE',
#  'BROUSSARD JOHNSIE LEE ETAL',
#  'MARSHALL MARGARET ET/AL',
#  'BENNETT FRANCES HEIRS',
#  'DA GRIFFIN PROPERTY INVEST LLC',
#  'PRATT BRENDA J',
#  'BLACKWELDER TRACY ALLEN',
#  'GROEPLER JAMES E &',
#  'CAPLE ROOSEVELT HEIRS',
#  'CAPLE CAROLYN VIRGINIA',
#  'UHURU ORA CAPLE',
#  'CAPLE PATRICIA ANN',
#  'STOVER JESSIE',
#  'PRATT SYDNEY',
#  'HUNTLEY JACQUELINE R REVOC TRU',
#  'VAZQUEZ IVAN & WIFE LAURA',
#  'BELLS CREEK LLC',
#  'HARGETT J VON JR LE &',
#  'WRIGHT DELORES C & JAMES H',
#  'CAPEL MARY FRANCES HEIRS',
#  'WALL SANDY HEIRS',
#  'PIEGER MARIA',
#  'PLEASANT HILL CHURCH',
#  'PRATT SYDNEY & BONNIE H',
#  'PRATT SIDNEY & BONNIE H',
#  'PLEASANT HILL BAPTIST CHURCH',
#  'PRATT MARTHA L ET AL',
#  'HELMS WILLIAM A & NANCY',
#  'SWICEGOOD KENNETH WAYNE III',
#  'ANSON COUNTY FARMS LLC',
#  'YEAKLE MICHAEL LYNN',
#  'VAUGHN TOMMY B',
#  'MORGAN RANDALL D',
#  'MORGAN RANDALL DIGGS',
#  'STEGALL TONYA HELMS',
#  'MARK TUCKER TIMBER CO LLC',
#  'RATLIFF WALTER A & ET AL',
#  'FERRYLAND CORP',
#  'MARTIN JASON SMITH',
#  'BAKER KIRK SHANNON',
#  'BAKER GLENN C & WIFE',
#  'PEE DEE BAPTIST CHURCH',
#  'BAKER KIRK S',
#  'REFUGE FARM LLC',
#  'DENNIS BENJAMIN ALLEN',
#  'HARRISON RICHARD DENNIS',
#  'COCHRAN MARY KATHERINE DENNIS',
#  'OATES DAVID TRENT',
#  'GATHINGS JILLA DENNIS',
#  'PATE JOHN THOMAS SR',
#  'MT ZION BAPTIST CHURCH',
#  'EVERGREEN TIMBERCO NC LLC',
#  'POPE EDWARD C & TERESA',
#  'HARDISON OTTO JAY',
#  'COBLE WILLIAM J & HELEN',
#  'POPE TERESA I',
#  'HUNTLEY SANDRA C & JUSTIN R',
#  'FINCHER GARY &',
#  'HUNTLEY JUSTIN ROBERT',
#  'POPE TERESA INGOLD &',
#  'COBLE RALPH H',
#  'COBLE JOHNNY H JR',
#  'BOWERS FRANK M & HELEN',
#  'SMITH KATHY S',
#  'CARUSO PATRICIA DALY',
#  'RORIE JERRY M & NAN',
#  'LEAR BRANDON TYLER',
#  'BRODIE JEAN I',
#  'BOSTIAN ROBERT P JR',
#  'HILDRETH JOY B',
#  'RICH JAMES SR & SHIRLEY A',
#  'RICH JAMES H SR & SHIRLEY A',
#  'TYNER TIMOTHY WAYNE & WIFE',
#  'STOUT LINDA B',
#  'BOSTIAN ROBERT PAUL JR',
#  'JOURNAL BROADCASTING',
#  'HAMILTON BRENDA L & MARTHA',
#  'FLEETTALK LLC',
#  'DOWNER BARBARA B',
#  'HILL STEPHEN P',
#  'GARRIS SHAUN & WIFE',
#  'GRIFFIN MAX LEE AND',
#  'GRIGGS MARY EARL HEIRS',
#  'HERRING ANNIE & AMOS MCLEOD &',
#  'TICE(NMI)BILLY LE & WIFE',
#  'HARRIS KIMBERLY L &',
#  'ARDEN DAISY ET AL',
#  'AUTRY LEE THOMAS',
#  'FLOOD ANNIE M',
#  'HORNE THEODORE JR',
#  'BESSIE CHAPEL CHURCH',
#  'HORNE WILLIAM W',
#  'AUTRY LUCILLE',
#  'HORNE WILLIAM',
#  'FREEMAN JAMES MICHAEL',
#  'GATHINGS CHRYSTAL CRISCO',
#  'LE TRUNG QUANG & WIFE',
#  'SHADES MOUNTAIN TIMBERCONC LLC',
#  'THOMPSON MARY LUCINDA',
#  'FLAKE CEMETERY',
#  'BURROUGHS ARLIE',
#  'WEST DAVID P &',
#  'WEST DAVID P & FRANCES W',
#  'ADAMS THOMAS & BASTIEN BUCHACA',
#  'MALONEY THEODORE ALONZO',
#  'MARTIN RONALD F',
#  'MARTIN EVELYN',
#  'LOCKHART FARMS LLC',
#  'GUY KENNETH EUGENE & WIFE',
#  'RATLIFF MITCHELL W &',
#  'CLARK CHARLES TIMOTHY',
#  'BURR JEFFREY &',
#  'BURR JEFFERY B & WIFE',
#  'BURR RENTAL LLC',
#  'BURR JEFFREY BRIAN',
#  'FALL BRANCH BAPTIST CHURCH',
#  'MORTON DUSTIN T',
#  'BURR MICHAEL WILSON',
#  'MORTON WILLIAM WAYNE LE & WIFE',
#  'MORTON LILLIE BURR &',
#  'STILLER ROY E &',
#  'MORTON LILLIE BURR',
#  'MORTON W WAYNE LE AND WIFE',
#  'MORTON TERESA BLEDSOE',
#  'MORTON RODNEY THOMAS',
#  'TUCKER THOMAS RAY',
#  'FORESTVILLE METHODIST CHURCH',
#  'SELLERS SHALAR D',
#  'GILMORE EDDIE H JR LE & WIFE',
#  'JOHNSON NATHAN DARRELL & WIFE',
#  'OLIVER ROBERT DARYL',
#  'ADAMS CHRISTI PATRICK',
#  'ADAMS WILLIE PATRICK &',
#  'ELO ENTERPRISES LLC',
#  'MOSS ROBERT GERALD & DEBORAH',
#  'GOODWIN HENRY J & WIFE',
#  'JAMES JEFFERY LEE',
#  'MOSS ROBERT G & DEBORAH',
#  'CASTRO ELLA C',
#  'WRIGHT LEE W',
#  'WRIGHT LEE',
#  'JOHNSON GARY LEE',
#  'HEDRICK B V SAND & GRAVEL',
#  'KNOPP NICHOLAS C',
#  'DUNLAP & MILLS',
#  'MOYA ANGELINE ETAL',
#  'WHITTAKER DAVID ROY & WIFE',
#  'ENGLISH MARGARET MICHELLE',
#  'EDWARDS CARLOS ROBERTO & WIFE',
#  'TANT DAVID W & WIFE',
#  'WEAVER DONALD STEVEN',
#  'TANT DAVID W & BETTY H',
#  'B V HEDRICK GRAVEL & SAND',
#  'RIZZO PETER A ET AL',
#  'CHEWNING CLARENCE A ET AL',
#  'PARRIS VICTORIA',
#  'BURNETTE BILLY W JR',
#  'RIZZO PETER A &',
#  'EDWARDS CARLOS &',
#  'DAVIS MICHAEL ALAN & WIFE',
#  'THOMPSON CHARLES EDWIN JR &',
#  'ARRINGTON NANCY S RUSSELL',
#  'TAYLOR BRIAN HARRIS',
#  'LOWE DAVID ET AL',
#  'PEGRAM BRENDA',
#  'NORTHCUTT MED C JR & EMELINE',
#  'PEGRAM BREMDA',
#  'CARTER CEMETERY',
#  'RUSSELL AGNES AMANDA LE',
#  'TARLTON CATHY D',
#  'ALLIGOOD JONATHAN',
#  'POE DARYL GLEN & WIFE',
#  'DOVE PAUL LORENZE',
#  'INGRAM WILLIE SENA',
#  'BROWN TIMOTHY JR & WIFE',
#  'JENKINS TIMMY DALE &',
#  'AARON HINSON FAMILY TRUST',
#  'POPLIN BETHANY',
#  'WEAVER STANFORD & MICHAEL',
#  'TARLTON CATHY M',
#  'HOOKS MARCIA E',
#  'WISNIEWSKI WILLIAM S',
#  'HINSON AARON FAMILY TRUST',
#  'HENRY SANDRA KAY LE',
#  'ATKINSON MARTHA & CLINT HEIRS',
#  'PEGRAM EDDIE B',
#  'JARMAN THOMAS R & CYNTHIA',
#  'LILES DANIEL MARSH',
#  'LILES JAMES BENFORD',
#  'WELIKA LAKE FISH HOUSE INC',
#  'ZEI & THLO FARM LLC',
#  'JOHNSON ARTHUR H & BETTY M',
#  'JORDAN TERRY & BECKY FAYE W',
#  'BIG ROCK FARM INC',
#  'TOWNSEND LETHA A',
#  'NETTLES CHRISTOPHER LEE',
#  'ALMOND ERSKIN YATES JR',
#  'TAYLOR ANDERSON C & LINDA G',
#  'CHEWNING OSCAR CHARLIE JR',
#  'BONSAL AMERICAN INC',
#  'GEORGIA-PACIFIC WFS LLC',
#  'HOLLEY MARY K &',
#  'ALLEN JOHN RICHARD LE',
#  'MCCORMICK JESSIE B',
#  'RAINWATER TAYLOR RAY',
#  'RATLIFF LINDA P & HUSBAND',
#  'GOODWIN JOSEPH M & WIFE',
#  'RATLIFF LINDA P',
#  'CHEWNING OSCAR C JR',
#  'PEGRAM SANDRA LYNN (STOGNER)',
#  'STOGNER BRYSON TODD',
#  'ELLIOTT MICHELLE REGINA',
#  'ROBERTS DONNA L',
#  'KOSKEY VERONICA & HUSBAND',
#  'PEGRAM PEGGY FRANCES',
#  'CAPALBO MARK J&LINDA L CAPALBO',
#  'GRECHO JEAN',
#  'JENKINS TIMMY D & WIFE',
#  'RATLIFF LINDA PEGRAM LE',
#  'MURDOCK ANNA LE',
#  'BROWN RICHARD JAMES',
#  'MCGRADY BRITTANY JANE',
#  'LITTLE WARREN Y & ABBIE',
#  'BROWN RICHARD J & PHYLLIS A M',
#  'STOGNER SANDRA P',
#  'GADDY JOE EDWARD',
#  'MCCORMICK JOSEPH N',
#  'HILDRETH ROBERT T & WANDA L',
#  'COLETRAIN WINCY HEIRS',
#  'GALLIMORE FARMS LLC',
#  'HENRY GROVE BAPTIST CHURCH',
#  'COX J C HEIRS',
#  'BARBER HUGH JR',
#  'HENRY GROVE BAPTIST CH  TRUSTE',
#  'ELLERBE LEOLA COLTRANE',
#  'ELLERBE LEOLA',
#  'ELLERBE LEOLA COLETRAIN',
#  'RATLIFF T C ETAL',
#  'CLOUD CARMIE DENNIS',
#  'HILDRETH SPARE SEAN',
#  'LITTLE THOMAS E',
#  'FORESTVILLE AME ZION CHURCH',
#  'NORTON CLEMENT R',
#  'CARAWAY ISAAC HEIRS',
#  'ZEI & THLO FARMS LLC',
#  'GALLIMORE DAVID WOODSON & WIFE',
#  'FLOWERS CHARLOTTE L',
#  'BENNETT MILDRED',
#  'HILL ANTWON EMON',
#  'BENNETT VERNON C & GLADYS',
#  'PRATT EFFIE S',
#  'ROBINSON ROSSIE JEAN',
#  'PRATT CHARLOTTE B HEIRS',
#  'HUGUE BETTY RAY',
#  'WARING JOAN BENNETT ETAL',
#  'BENNETT JUNE AARON & WIFE',
#  'LEAR TONY K & PAULA W',
#  'GREGORY MARY ONNIE JONES',
#  'DIGGS WANDA S',
#  'COVIL LINDA D',
#  'KNOTTS JAMES C & WIFE KRISTY',
#  'GROOMS BARRY MICHAEL SR',
#  'BEAVER WAYNE EDWARD JR',
#  'PAUL MARGIE TUCKER LE',
#  'PRICE BOBBIE JEAN',
#  'RODRIGUEZ LOURDES ALEXANDRA',
#  'MCLENDON AMBER NICOLE',
#  'INGRAM ROBERT',
#  'LOWERY JOHN ERIC',
#  'HARRINGTON GERTRUDE L',
#  'HOOKS DONALD H & GLENDA',
#  'NAPIER INVESTMENTS LLC',
#  'WIGGINS LEIGH HILDRETH',
#  'GRAY WILLIAM SCOTT',
#  'KNOTTS WAYNE & ELIZABETH W',
#  'TEAL RYAN L & WIFE',
#  'SEXTON BARBARA D',
#  'PARKER BILLY LEE & WIFE',
#  'BURR JUSTIN MICHAEL',
#  'KNOPP TIMOTHY KEVIN & WINDY G',
#  'KNOPP TIMOTHY K & WINDY A',
#  'WILLIAMS KENNETH L JR &',
#  'LILES MARKUS L',
#  'SHEPPARD CHARLES',
#  'GUM SPRINGS BAPTIST CHURCH',
#  'NIVENS ALVIN ORREN & WIFE',
#  'BENTON CHRISTOPHER',
#  'GREGORY MARY ONNIE JONES TR',
#  'HARRINGTON WALTER STEVE ETAL',
#  'GREGORY MARY ONNIE JONES FAMIL',
#  'FUNDERBURKE MARGARET LE',
#  'EDWARDS ELIZABETH THOMPSON',
#  'GREGORY MARY ONNIE JONES TRUST',
#  'LEE PENNY LOWERY ETAL',
#  'RIVERS MILDRED (MICKIE)',
#  'RIVERS MILDRED',
#  'CARPENTER CLARENCE FULTON JR &',
#  'LOWE MARK T',
#  'KOZHAYEV PAVEL',
#  'HORNWOOD INC',
#  'INGRAM RENA T (WHITLEY)',
#  'SEABOARD AIRLINE RAILROAD',
#  'BARNHILL RONALD LEE & CAROLE',
#  'JONES B K HEIRS',
#  'RODRIGUEZ PERFECTO',
#  'MCCORMICK EDITH HEIRS',
#  'ATKINSON JOHN COURTNEY',
#  'SEABOARD COASTLINE RR',
#  'HEDRICK B V GRAVEL AND SAND CO',
#  'BARNHILL RONALD L &',
#  'BRITT JAMES & WIFE',
#  'CHILSON GROVE CHURCH',
#  'HARRIS PAULETTE',
#  'MCCORMICK JOHN G',
#  'JONES BENJAMIN KIRBY II &',
#  'BENNETT ALVIN DALLAS &',
#  'KNOTTS WAYNE M',
#  'SMITH ANDREW J',
#  'LITTLE CHARLES L JR &',
#  'LILES ROSALYNN CHRISTIE',
#  'GRACE ROSA',
#  'CLARK LARRY D & DEBORAH G',
#  'CHAVIS ANDREW',
#  'WEED WALTER W &',
#  'POLSON VICKIE M',
#  'LOVETT AULDON MARTIN & TERRY A',
#  'LITTLE RE LIMITED PARTNERSHIP',
#  'SHEPPARD WOOD PRODUCTS',
#  'AYDELETTE REBECCA ANN A ETAL',
#  'DEESE SAMUEL TAYLOR JR',
#  'ADAMS ANGELIA G',
#  'STATON H B MRS',
#  'EDWARDS WOOD PRODUCTS INC',
#  'LEE MATTHEW BRACE &',
#  'LITTLE DORA ANNE TRUST',
#  'HARDISON HAZEL TRUST ET/AL',
#  'MARK TERRENCE M JR & WIFE',
#  'HERRINGTON CLIFFORD R & WIFE',
#  'EBENEZER CHURCH',
#  'MORGAN JAMES R & WIFE',
#  'MORGAN JAMES R & BRENDA',
#  'MORGAN JAMES RALPH &',
#  'MORGAN JAMES RALPH & BRENDA L',
#  ...]

# %% [markdown]
# The best way to get information on residential units (RUs) is to use the name of the primary owner. Using the assumption that commercial units will have labels like 'LLC' or 'Ventures', we can filter for RUs.
# Notes: We need to check whether commercial units can be registered under the name of the property owner. There are also 175 nulls in this column.

# %%
key= ["STATE","STATEOF","LLC","VENTURES","CHURCH", "INC", "ASS", "DUKE", "TRUST", "PROPERTY", "PROPERTIES","COUNTY", "CEMETERY", "CORP", "HOLDINGS", "ELECTRIC", "WOODYARD", "CORP", "FARMS"]
notRU=[]
for i in data['OWNNAME']:
    try:
        notRU.append(bool([ele for ele in key if(ele in i)]))
    except:
        notRU.append(None)

# %%
data['notRU']=notRU
data['notRU'].value_counts() #So there are 16,176 Residential Units
# Out:
# False    16176
# True      2523
# Name: notRU, dtype: int64

# %% [markdown]
# As a next step, we can improve the filtering. Further, we can judge nonRUs if they area they cover seem unusual.

# %%
data[data['notRU']==False].GISACRES.describe()
# Out:
# count    16176.000000
# mean        13.265803
# std         45.700110
# min          0.005498
# 25%          0.498611
# 50%          1.494133
# 75%          8.265828
# max       2883.638974
# Name: GISACRES, dtype: float64

# %%
data[(data['notRU']==False) & (data['GISACRES']>500)] #setting threshold of 500
# Out:
#            ALTPARNO CNTYFIPS CNTYNAME     GISACRES   GNISID  IMPROVVAL  \
# 571    742600234166      007    Anson   693.901678  1008534        0.0
# 774    742300358033      007    Anson   619.253441  1008534        0.0
# 1539   740700796007      007    Anson   588.950717  1008534   161700.0
# 1558   740700288449      007    Anson   577.019585  1008534        0.0
# 2579   740200426850      007    Anson   780.901378  1008534   125400.0
# 3025   732900471026      007    Anson  2883.638974  1008534   268600.0
# 3420   656000227758      007    Anson   537.818889  1008534        0.0
# 7203   648300404136      007    Anson   673.839651  1008534     8200.0
# 7285   648100447935      007    Anson   705.119904  1008534        0.0
# 12329  646100943720      007    Anson   532.946410  1008534    35900.0
# 13060  645300908877      007    Anson   948.794155  1008534     6200.0
# 13194  645200347140      007    Anson   581.050647  1008534        0.0
# 14247  644400036590      007    Anson  1171.538559  1008534     9300.0
# 14293  644300277817      007    Anson   747.930910  1008534        0.0
# 14420  644000015087      007    Anson   790.290556  1008534        0.0
# 15210  643500428056      007    Anson   684.595908  1008534        0.0
# 15429  643000782440      007    Anson   595.008671  1008534        0.0
# 16552  642300320394      007    Anson   526.395082  1008534        0.0
#
#          LANDVAL                                            MAILADD  \
# 571     445300.0                  PO BOX 575" "NORWOOD" "28128-0000
# 774     618900.0               PO BOX 418" "LILESVILLE" "28091-0000
# 1539    289600.0  78 CROSSBILL LANE UNIT 3" "HENDERSONVILLE" "28...
# 1558    218100.0              122 SIDES RD" "MT GILEAD" "27306-0000
# 2579    542700.0             2323 DIGGS RD" "WADESBORO" "28170-0000
# 3025   1858200.0               PO DRAWER 1449" "CHERAW" "29520-0000
# 3420    256800.0                   PO BOX 36" "NORWOOD" "28128-0000
# 7203    443800.0                PO BOX 215" "WADESBORO" "28170-0000
# 7285    452800.0  9000 HWY 49N PO BOX 535" "MT PLEASANT" "28124-...
# 12329   389200.0  28838 KENDALLS CHURCH ROAD" "RICHFIELD" "28137...
# 13060   377900.0               PO BOX 219" "MARSHVILLE" "28103-0000
# 13194   221800.0               PO BOX 219" "MARSHVILLE" "28103-0000
# 14247   462600.0       107 WELLING CIRCLE" "GREENVILLE" "29607-0000
# 14293   279300.0                   PO BOX 7" "PAGELAND" "29728-0000
# 14420   298800.0      11912 MANDARIN RD" "JACKSONVILLE" "32223-0000
# 15210   258800.0         18 PLANTERS ROW" "HILTON HEAD" "29928-0000
# 15429   226200.0  300 NORTH THIRD ST SUITE 320" "WILMINGTON" "28...
# 16552   198900.0               PO BOX 219" "MARSHVILLE" "28103-0000
#
#                 MCITY MSTATE  ...             SOURCEAGNT SOURCEREF SSTATE  \
# 571           NORWOOD     NC  ...  Anson County Assessor  239_0308     NC
# 774        LILESVILLE     NC  ...  Anson County Assessor  072_0172     NC
# 1539   HENDERSONVILLE     NC  ...  Anson County Assessor  190_0879     NC
# 1558        MT GILEAD     NC  ...  Anson County Assessor  249_0473     NC
# 2579        WADESBORO     NC  ...  Anson County Assessor  450_0198     NC
# 3025           CHERAW     SC  ...  Anson County Assessor  561_0222     NC
# 3420          NORWOOD     NC  ...  Anson County Assessor  137_0310     NC
# 7203        WADESBORO     NC  ...  Anson County Assessor  134_0514     NC
# 7285      MT PLEASANT     NC  ...  Anson County Assessor  619_0307     NC
# 12329       RICHFIELD     NC  ...  Anson County Assessor  025_0049     NC
# 13060      MARSHVILLE     NC  ...  Anson County Assessor  068_0093     NC
# 13194      MARSHVILLE     NC  ...  Anson County Assessor  038_0105     NC
# 14247      GREENVILLE     SC  ...  Anson County Assessor  294_0001     NC
# 14293        PAGELAND     SC  ...  Anson County Assessor  815_0267     NC
# 14420    JACKSONVILLE     FL  ...  Anson County Assessor  345_0011     NC
# 15210     HILTON HEAD     SC  ...  Anson County Assessor  937_0088     NC
# 15429      WILMINGTON     NC  ...  Anson County Assessor  254_0364     NC
# 16552      MARSHVILLE     NC  ...  Anson County Assessor  228_0246     NC
#
#       STCNTYFIPS STFIPS STNAME  STRUCTYEAR  TRANSFDATE  \
# 571        37007     37     NC           0  2022-12-26
# 774        37007     37     NC           0  2022-12-26
# 1539       37007     37     NC           0  2022-12-26
# 1558       37007     37     NC           0  2022-12-26
# 2579       37007     37     NC           0  2022-12-26
# 3025       37007     37     NC           0  2022-12-26
# 3420       37007     37     NC           0  2022-12-26
# 7203       37007     37     NC           0  2022-12-26
# 7285       37007     37     NC           0  2022-12-26
# 12329      37007     37     NC           0  2022-12-26
# 13060      37007     37     NC           0  2022-12-26
# 13194      37007     37     NC           0  2022-12-26
# 14247      37007     37     NC           0  2022-12-26
# 14293      37007     37     NC           0  2022-12-26
# 14420      37007     37     NC           0  2022-12-26
# 15210      37007     37     NC           0  2022-12-26
# 15429      37007     37     NC           0  2022-12-26
# 16552      37007     37     NC           0  2022-12-26
#
#                              geometry  notRU
# 571    POINT (1721129.563 462337.057)  False
# 774    POINT (1723776.753 435342.485)  False
# 1539   POINT (1707429.862 479044.006)  False
# 1558   POINT (1702553.891 478103.354)  False
# 2579   POINT (1705949.000 422238.161)  False
# 3025   POINT (1718998.563 396489.762)  False
# 3420   POINT (1663933.806 502111.422)  False
# 7203   POINT (1684660.867 429354.731)  False
# 7285   POINT (1686065.478 412301.724)  False
# 12329  POINT (1669351.769 413391.285)  False
# 13060  POINT (1660385.975 427680.424)  False
# 13194  POINT (1653779.463 424241.017)  False
# 14247  POINT (1638619.548 441879.654)  False
# 14293  POINT (1642610.955 437800.479)  False
# 14420  POINT (1640780.583 401135.530)  False
# 15210  POINT (1635148.747 451644.265)  False
# 15429  POINT (1634950.091 403262.340)  False
# 16552  POINT (1623320.958 432398.034)  False
#
# [18 rows x 29 columns]

# %%
data[(data['notRU']==False) & (data['GISACRES']>500)]['OWNNAME'] #so remove some of these in the future
# Out:
# 571            CLODFELTER T LYNN & WIFE
# 774        HEDRICK B V GRAVEL & SAND CO
# 1539                 BRUTON JEFFERSON H
# 1558             SIDES PRESTON EUGENE &
# 2579       OAKS RONALD THOMAS & PATSY S
# 3025       MCLEOD PARTNERS LIMITED PART
# 3420                   BEACHUM SHERRY A
# 7203              CAPEL EVELYN REDFEARN
# 7285        PIEDMONT HARDWOOD LUMBER CO
# 12329               BURLESON ANDREW W &
# 13060            EDWARDS TIMBER COMPANY
# 13194            EDWARDS TIMBER COMPANY
# 14247         LITTLE FAMILY PARTNERSHIP
# 14293           DAVID BALL TUCKER ET AL
# 14420    HUNTLEY FAMILY LIMITED PRTNSHP
# 15210       CAUDLE ABIGAIL SUZANNE ETAL
# 15429          BELL CREEK LAND & TIMBER
# 16552                 EDWARDS TIMBER CO
# Name: OWNNAME, dtype: object
